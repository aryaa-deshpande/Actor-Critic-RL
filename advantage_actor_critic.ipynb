# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import gymnasium as gym
import matplotlib.pyplot as plt
from collections import deque
import threading
import torch.multiprocessing as mp
import copy

# Set seed for reproducibility
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
class SharedActorCritic(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_actions):
        super().__init__()

        self.shared = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU()
        )

        self.actorHead = nn.Sequential(
            nn.Linear(hidden_dim,num_actions),
            nn.Softmax(dim=-1)
        )

        self.criticHead = nn.Sequential(
            nn.Linear(hidden_dim, 1)
        )
    
    def forward(self,x):
        shared_output = self.shared(x)
        actorHead_output = self.actorHead(shared_output)
        criticHead_output = self.criticHead(shared_output)

        return actorHead_output, criticHead_output

# %%
model = SharedActorCritic(4,128,2)
model.share_memory()

optimizer = optim.Adam(model.parameters(), lr = 1e-3)

# %%
all_rewards = {0: [], 1: []}
def workers(thread_id, global_model, optimizer, num_episodes, lock, all_rewards):
    env = gym.make('CartPole-v1')

    for episode in range(num_episodes):
        obs,_ = env.reset()

        local_model = copy.deepcopy(global_model)

        log_probs = []
        values = []
        rewards = []


        done = False
        while not done:
            obs_tensor = torch.FloatTensor(obs).unsqueeze(0)
            action_probs, value = local_model(obs_tensor)
            dist = torch.distributions.Categorical(action_probs)
            action = dist.sample()
            prob = dist.log_prob(action)
            log_probs.append(prob)

            values.append(value.squeeze())

            action = action.item()
            obs, reward, terminated, truncated, info = env.step(action)
            rewards.append(reward)
            if terminated or truncated:
                done = True
        
        returns = []
        R = 0
        gamma = 0.99

        for reward in reversed(rewards):
            R = reward + gamma * R
            returns.insert(0, R)

        returns_tensor = torch.tensor(returns, dtype=torch.float32)
        log_probs_tensor = torch.stack(log_probs)
        values_tensor = torch.stack(values)

        advantage = (returns_tensor - values_tensor).detach()

        actor_loss = -(log_probs_tensor*advantage).mean()
        critic_loss = F.mse_loss(values_tensor,returns_tensor)

        with lock:
            optimizer.zero_grad()

            total_loss = actor_loss + critic_loss
            total_loss.backward()

            torch.nn.utils.clip_grad_norm_(global_model.parameters(), max_norm=0.5)

            optimizer.step()
            all_rewards[thread_id].append(sum(rewards))
            print(f"Thread {thread_id} | Episode {episode} | Reward: {sum(rewards)}")

# %%
lock = threading.Lock()
threads = []
for i in range(2):
    t = threading.Thread(target=workers, args=(i, model, optimizer, 300, lock, all_rewards))
    threads.append(t)
    t.start()

for t in threads:
    t.join()
# Out:
# Thread 0 | Episode 0 | Reward: 95.0
# Thread 1 | Episode 0 | Reward: 216.0
# Thread 0 | Episode 1 | Reward: 145.0
# Thread 1 | Episode 1 | Reward: 146.0
# Thread 0 | Episode 2 | Reward: 27.0
# Thread 1 | Episode 2 | Reward: 126.0
# Thread 0 | Episode 3 | Reward: 139.0
# Thread 1 | Episode 3 | Reward: 187.0
# Thread 0 | Episode 4 | Reward: 119.0
# Thread 1 | Episode 4 | Reward: 139.0
# Thread 0 | Episode 5 | Reward: 217.0
# Thread 1 | Episode 5 | Reward: 103.0
# Thread 0 | Episode 6 | Reward: 190.0
# Thread 1 | Episode 6 | Reward: 204.0
# Thread 0 | Episode 7 | Reward: 28.0
# Thread 0 | Episode 8 | Reward: 123.0
# Thread 1 | Episode 7 | Reward: 165.0
# Thread 0 | Episode 9 | Reward: 148.0
# Thread 1 | Episode 275 | Reward: 150.0
# Thread 0 | Episode 271 | Reward: 259.0
# Thread 1 | Episode 276 | Reward: 169.0
# Thread 0 | Episode 272 | Reward: 154.0
# Thread 1 | Episode 277 | Reward: 38.0
# Thread 1 | Episode 278 | Reward: 17.0
# Thread 0 | Episode 273 | Reward: 126.0
# Thread 1 | Episode 279 | Reward: 129.0
# Thread 0 | Episode 274 | Reward: 155.0
# Thread 1 | Episode 280 | Reward: 264.0
# Thread 0 | Episode 275 | Reward: 145.0
# Thread 1 | Episode 281 | Reward: 87.0
# Thread 0 | Episode 276 | Reward: 72.0
# Thread 1 | Episode 282 | Reward: 150.0
# Thread 0 | Episode 277 | Reward: 191.0
# Thread 1 | Episode 283 | Reward: 65.0
# Thread 0 | Episode 278 | Reward: 147.0
# Thread 1 | Episode 284 | Reward: 106.0
# Thread 0 | Episode 279 | Reward: 127.0
# Thread 1 | Episode 285 | Reward: 27.0
# Thread 0 | Episode 280 | Reward: 160.0
# Thread 1 | Episode 286 | Reward: 184.0
# Thread 0 | Episode 281 | Reward: 137.0
# Thread 1 | Episode 287 | Reward: 54.0
# Thread 0 | Episode 282 | Reward: 173.0
# Thread 1 | Episode 288 | Reward: 151.0
# Thread 0 | Episode 283 | Reward: 155.0
# Thread 1 | Episode 289 | Reward: 168.0
# Thread 0 | Episode 284 | Reward: 20.0
# Thread 1 | Episode 290 | Reward: 22.0
# Thread 1 | Episode 291 | Reward: 43.0
# Thread 0 | Episode 285 | Reward: 153.0
# Thread 1 | Episode 292 | Reward: 108.0
# Thread 0 | Episode 286 | Reward: 116.0
# Thread 1 | Episode 293 | Reward: 194.0
# Thread 0 | Episode 287 | Reward: 198.0
# Thread 1 | Episode 294 | Reward: 203.0
# Thread 0 | Episode 288 | Reward: 219.0
# Thread 1 | Episode 295 | Reward: 150.0
# Thread 0 | Episode 289 | Reward: 189.0
# Thread 1 | Episode 296 | Reward: 208.0
# Thread 0 | Episode 290 | Reward: 167.0
# Thread 1 | Episode 297 | Reward: 29.0
# Thread 0 | Episode 291 | Reward: 116.0
# Thread 1 | Episode 298 | Reward: 161.0
# Thread 0 | Episode 292 | Reward: 153.0
# Thread 1 | Episode 299 | Reward: 125.0
# Thread 0 | Episode 293 | Reward: 189.0
# Thread 0 | Episode 294 | Reward: 226.0
# Thread 0 | Episode 295 | Reward: 120.0
# Thread 0 | Episode 296 | Reward: 20.0
# Thread 0 | Episode 297 | Reward: 163.0
# Thread 0 | Episode 298 | Reward: 325.0
# Thread 0 | Episode 299 | Reward: 199.0

# %%
plt.figure(figsize=(12, 5))
plt.plot(all_rewards[0], label='Thread 0', alpha=0.7)
plt.plot(all_rewards[1], label='Thread 1', alpha=0.7)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('A3C Training CartPole-v1')
plt.legend()
plt.show()

# %%
model.eval()
eval_rewards = []
env = gym.make('CartPole-v1')

for episode in range(10):
    obs, _ = env.reset()
    total_reward = 0
    done = False
    
    while not done:
        obs_tensor = torch.FloatTensor(obs).unsqueeze(0)

        action_probs, value = model(obs_tensor)
        action = torch.argmax(action_probs)
        action = action.item()
        obs, reward, terminated, truncated, info = env.step(action)

        total_reward += reward

        if terminated or truncated:
            done = True
    
    eval_rewards.append(total_reward)
    print(f"Eval Episode {episode} | Reward: {total_reward}")
# Out:
# Eval Episode 0 | Reward: 166.0
# Eval Episode 1 | Reward: 175.0
# Eval Episode 2 | Reward: 187.0
# Eval Episode 3 | Reward: 159.0
# Eval Episode 4 | Reward: 164.0
# Eval Episode 5 | Reward: 166.0
# Eval Episode 6 | Reward: 191.0
# Eval Episode 7 | Reward: 164.0
# Eval Episode 8 | Reward: 182.0
# Eval Episode 9 | Reward: 166.0

# %%
plt.figure(figsize=(8, 4))
plt.plot(eval_rewards, marker='o')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('A3C Evaluation CartPole-v1 (Greedy Policy)')
plt.xticks(range(10))
plt.show()

# %%
# %pip install "gymnasium[other]"
# Out:
# Requirement already satisfied: gymnasium[other] in /opt/homebrew/lib/python3.10/site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /opt/homebrew/lib/python3.10/site-packages (from gymnasium[other]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/homebrew/lib/python3.10/site-packages (from gymnasium[other]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/aryaapareshdeshpande/Library/Python/3.10/lib/python/site-packages (from gymnasium[other]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/homebrew/lib/python3.10/site-packages (from gymnasium[other]) (0.0.4)
# Collecting moviepy>=1.0.0 (from gymnasium[other])
#   Downloading moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: matplotlib>=3.0 in /opt/homebrew/lib/python3.10/site-packages (from gymnasium[other]) (3.10.7)
# Collecting opencv-python>=3.0 (from gymnasium[other])
#   Downloading opencv_python-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: seaborn>=0.13 in /opt/homebrew/lib/python3.10/site-packages (from gymnasium[other]) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/aryaapareshdeshpande/Library/Python/3.10/lib/python/site-packages (from matplotlib>=3.0->gymnasium[other]) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.0->gymnasium[other]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aryaapareshdeshpande/Library/Python/3.10/lib/python/site-packages (from matplotlib>=3.0->gymnasium[other]) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/aryaapareshdeshpande/Library/Python/3.10/lib/python/site-packages (from moviepy>=1.0.0->gymnasium[other]) (5.2.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from moviepy>=1.0.0->gymnasium[other]) (2.37.3)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy>=1.0.0->gymnasium[other])
#   Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting proglog<=1.0.0 (from moviepy>=1.0.0->gymnasium[other])
#   Downloading proglog-0.1.12-py3-none-any.whl.metadata (794 bytes)
# Collecting python-dotenv>=0.10 (from moviepy>=1.0.0->gymnasium[other])
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting pillow>=8 (from matplotlib>=3.0->gymnasium[other])
#   Using cached pillow-11.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.10/site-packages (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[other]) (4.67.3)
# Requirement already satisfied: six>=1.5 in /Users/aryaapareshdeshpande/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[other]) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in /opt/homebrew/lib/python3.10/site-packages (from seaborn>=0.13->gymnasium[other]) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[other]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.10/site-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[other]) (2025.2)
# Downloading moviepy-2.2.1-py3-none-any.whl (129 kB)
# Using cached pillow-11.3.0-cp310-cp310-macosx_11_0_arm64.whl (4.7 MB)
# Downloading proglog-0.1.12-py3-none-any.whl (6.3 kB)
# Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 6.7 MB/s  0:00:03 eta 0:00:01
# Downloading opencv_python-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl (46.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 8.6 MB/s  0:00:05m0:00:0100:01
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, proglog, pillow, opencv-python, imageio_ffmpeg, moviepy
#   Attempting uninstall: pillow
#     Found existing installation: pillow 12.0.0
#     Uninstalling pillow-12.0.0:
#       Successfully uninstalled pillow-12.0.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [moviepy]m3/6 [opencv-python]
# Successfully installed imageio_ffmpeg-0.6.0 moviepy-2.2.1 opencv-python-4.13.0.92 pillow-11.3.0 proglog-0.1.12 python-dotenv-1.2.2
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from save_rendered_video import run_and_record_one_episode

def greedy_policy(obs):
    obs_tensor = torch.FloatTensor(obs).unsqueeze(0)
    with torch.no_grad():
        action_probs, _ = model(obs_tensor)
    return torch.argmax(action_probs).item()

run_and_record_one_episode('CartPole-v1', greedy_policy, out_dir='videos')
# Out:
# /opt/homebrew/lib/python3.10/site-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /Users/aryaapareshdeshpande/Desktop/Reinforcement Learning/Assignment 3 - Checkpoint attached files Apr 9, 2026 547 PM/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# /opt/homebrew/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Saved video in videos. Episode reward: 179.0, steps: 179

# %%
torch.save(model.state_dict(), 'a3_part_2_a3c_cartpole_aryaapar.pth')
